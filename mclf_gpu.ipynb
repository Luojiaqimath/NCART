# %%
import numpy as np
import pickle
from sklearn.datasets import load_iris
import os
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from ncart import NCARClassifier

# %%
data = load_iris()  
X = data.data.astype(np.float32)
y = data.target
feature_names = data.feature_names

# %%
model = NCARClassifier(epochs=100, n_trees=8, n_layers=2, n_selected=6)
model.fit(X, y)
# Out:
# On Device:  cuda:0
# Multi-class classification
# Epoch 0: Train Loss 1.103770
# Epoch 1: Train Loss 1.099233
# Epoch 2: Train Loss 1.094765
# Epoch 3: Train Loss 1.090365
# Epoch 4: Train Loss 1.086036
# Epoch 5: Train Loss 1.081794
# Epoch 6: Train Loss 1.077627
# Epoch 7: Train Loss 1.073536
# Epoch 8: Train Loss 1.069510
# Epoch 9: Train Loss 1.065548
# Epoch 10: Train Loss 1.061649
# Epoch 11: Train Loss 1.057810
# Epoch 12: Train Loss 1.054059
# Epoch 13: Train Loss 1.050366
# Epoch 14: Train Loss 1.046745
# Epoch 15: Train Loss 1.043182
# Epoch 16: Train Loss 1.039706
# Epoch 17: Train Loss 1.036296
# Epoch 18: Train Loss 1.032959
# Epoch 19: Train Loss 1.029720
# Epoch 20: Train Loss 1.026539
# Epoch 21: Train Loss 1.023417
# Epoch 22: Train Loss 1.020340
# Epoch 23: Train Loss 1.017310
# Epoch 24: Train Loss 1.014319
# Epoch 25: Train Loss 1.011391
# Epoch 26: Train Loss 1.008529
# Epoch 27: Train Loss 1.005716
# Epoch 28: Train Loss 1.002940
# Epoch 29: Train Loss 1.000206
# Epoch 30: Train Loss 0.997523
# Epoch 31: Train Loss 0.994903
# Epoch 32: Train Loss 0.992330
# Epoch 33: Train Loss 0.989792
# Epoch 34: Train Loss 0.987286
# Epoch 35: Train Loss 0.984824
# Epoch 36: Train Loss 0.982387
# Epoch 37: Train Loss 0.979959
# Epoch 38: Train Loss 0.977552
# Epoch 39: Train Loss 0.975168
# Epoch 40: Train Loss 0.972798
# Epoch 41: Train Loss 0.970445
# Epoch 42: Train Loss 0.968111
# Epoch 43: Train Loss 0.965787
# Epoch 44: Train Loss 0.963476
# Epoch 45: Train Loss 0.961183
# Epoch 46: Train Loss 0.958905
# Epoch 47: Train Loss 0.956638
# Epoch 48: Train Loss 0.954382
# Epoch 49: Train Loss 0.952130
# Epoch 50: Train Loss 0.949887
# Epoch 51: Train Loss 0.947654
# Epoch 52: Train Loss 0.945420
# Epoch 53: Train Loss 0.943179
# Epoch 54: Train Loss 0.940946
# Epoch 55: Train Loss 0.938725
# Epoch 56: Train Loss 0.936513
# Epoch 57: Train Loss 0.934306
# Epoch 58: Train Loss 0.932102
# Epoch 59: Train Loss 0.929902
# Epoch 60: Train Loss 0.927692
# Epoch 61: Train Loss 0.925489
# Epoch 62: Train Loss 0.923303
# Epoch 63: Train Loss 0.921139
# Epoch 64: Train Loss 0.918985
# Epoch 65: Train Loss 0.916836
# Epoch 66: Train Loss 0.914699
# Epoch 67: Train Loss 0.912574
# Epoch 68: Train Loss 0.910472
# Epoch 69: Train Loss 0.908386
# Epoch 70: Train Loss 0.906310
# Epoch 71: Train Loss 0.904236
# Epoch 72: Train Loss 0.902171
# Epoch 73: Train Loss 0.900116
# Epoch 74: Train Loss 0.898059
# Epoch 75: Train Loss 0.896005
# Epoch 76: Train Loss 0.893972
# Epoch 77: Train Loss 0.891956
# Epoch 78: Train Loss 0.889955
# Epoch 79: Train Loss 0.887964
# Epoch 80: Train Loss 0.886003
# Epoch 81: Train Loss 0.884064
# Epoch 82: Train Loss 0.882139
# Epoch 83: Train Loss 0.880219
# Epoch 84: Train Loss 0.878321
# Epoch 85: Train Loss 0.876443
# Epoch 86: Train Loss 0.874575
# Epoch 87: Train Loss 0.872718
# Epoch 88: Train Loss 0.870874
# Epoch 89: Train Loss 0.869049
# Epoch 90: Train Loss 0.867236
# Epoch 91: Train Loss 0.865432
# Epoch 92: Train Loss 0.863641
# Epoch 93: Train Loss 0.861862
# Epoch 94: Train Loss 0.860099
# Epoch 95: Train Loss 0.858348
# Epoch 96: Train Loss 0.856607
# Epoch 97: Train Loss 0.854870
# Epoch 98: Train Loss 0.853141
# Epoch 99: Train Loss 0.851421
# ([1.1037698984146118,
#   1.09923255443573,
#   1.0947648286819458,
#   1.0903652906417847,
#   1.0860357284545898,
#   1.0817943811416626,
#   1.077627182006836,
#   1.073535680770874,
#   1.0695103406906128,
#   1.0655478239059448,
#   1.0616488456726074,
#   1.0578103065490723,
#   1.0540592670440674,
#   1.0503662824630737,
#   1.0467453002929688,
#   1.0431816577911377,
#   1.039705753326416,
#   1.0362956523895264,
#   1.0329593420028687,
#   1.0297201871871948,
#   1.0265394449234009,
#   1.023416519165039,
#   1.0203403234481812,
#   1.0173102617263794,
#   1.0143194198608398,
#   1.0113914012908936,
#   1.0085291862487793,
#   1.0057162046432495,
#   1.0029401779174805,
#   1.0002059936523438,
#   0.99752277135849,
#   0.9949028491973877,
#   0.9923295378684998,
#   0.9897924065589905,
#   0.987285852432251,
#   0.9848244190216064,
#   0.982386589050293,
#   0.9799585938453674,
#   0.9775524735450745,
#   0.9751680493354797,
#   0.9727982878684998,
#   0.9704446196556091,
#   0.9681107401847839,
#   0.9657870531082153,
#   0.9634764790534973,
#   0.9611833691596985,
#   0.9589052200317383,
#   0.9566381573677063,
#   0.95438152551651,
#   0.9521300196647644,
#   0.9498867988586426,
#   0.9476544260978699,
#   0.9454204440116882,
#   0.9431793093681335,
#   0.9409457445144653,
#   0.9387248754501343,
#   0.9365127682685852,
#   0.9343060255050659,
#   0.9321022629737854,
#   0.9299017190933228,
#   0.927691638469696,
#   0.9254888892173767,
#   0.9233032464981079,
#   0.9211394190788269,
#   0.9189851880073547,
#   0.916836142539978,
#   0.9146990180015564,
#   0.9125735759735107,
#   0.9104723930358887,
#   0.9083856344223022,
#   0.9063101410865784,
#   0.904236376285553,
#   0.9021705985069275,
#   0.9001158475875854,
#   0.8980594873428345,
#   0.8960052728652954,
#   0.8939719796180725,
#   0.8919558525085449,
#   0.8899551630020142,
#   0.8879641890525818,
#   0.8860027194023132,
#   0.8840640187263489,
#   0.8821385502815247,
#   0.8802188038825989,
#   0.8783206343650818,
#   0.8764433860778809,
#   0.8745750188827515,
#   0.8727179169654846,
#   0.8708739280700684,
#   0.8690493702888489,
#   0.8672361969947815,
#   0.8654324412345886,
#   0.8636413812637329,
#   0.861862301826477,
#   0.8600992560386658,
#   0.8583483099937439,
#   0.8566072583198547,
#   0.8548699021339417,
#   0.853141188621521,
#   0.8514207005500793],
#  [])

# %%
importance = model.get_importance()

# %%
# Create a DataFrame with feature names and importance scores
feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Plot feature importances using Seaborn
plt.figure()
sns.barplot(x='Importance', y='Feature', data=feature_importance_df, width=0.6)
plt.title('Feature Importances', fontsize=12)
plt.xlabel('Importance Score', fontsize=15)
plt.ylabel('Features', fontsize=15)
plt.tick_params(axis='both', which='major', labelsize=12)
plt.tight_layout()
plt.show()
